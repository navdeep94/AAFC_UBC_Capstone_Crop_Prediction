# %%
import pandas as pd
import numpy as np

# %%
aafc_data=pd.read_csv("aafc_data.txt",index_col=None)
aafc_data.head()
# Out:
#    Unnamed: 0   TWP_ID  ECODISTRICT_ID  YEAR  YieldKgAcre  SumPcpn18_20  \
# 0           0  00101E1           852.0  2010   867.766846          53.6
# 1           1  00101W1           852.0  2010   673.685028          57.2
# 2           2  00101W2           796.0  2010   824.303864          39.0
# 3           3  00102E1           853.0  2010  1006.708496          37.5
# 4           4  00102W1           852.0  2010   869.040283          57.2
#
#    SumPcpn19_21  SumPcpn20_22  SumPcpn21_23  SumPcpn22_24  ...  \
# 0         111.1         109.7         117.9          46.4  ...
# 1         114.7         110.5         114.0          46.2  ...
# 2          96.4         109.8         101.2         111.4  ...
# 3         158.2         157.8         161.4          46.9  ...
# 4         114.7         110.5         114.0          46.2  ...
#
#    SoilMoisture29_31  SoilMoisture30_32  SoilMoisture31_33  SoilMoisture32_34  \
# 0          16.960125          18.766207          17.186998          15.461519
# 1          16.328520          17.926029          16.787544          14.779726
# 2          13.117879          12.869142          12.831834          14.126196
# 3          17.060778          18.699156          17.345822          15.998957
# 4          16.050993          17.556860          16.612026          14.480150
#
#    SoilMoisture33_35  SoilMoisture34_36  SoilMoisture35_37  SoilMoisture36_38  \
# 0          19.738222          22.958089          27.206203          26.480087
# 1          20.245149          23.608204          28.560990          27.324254
# 2          16.385776          18.650751          20.287069          20.514132
# 3          20.091525          22.761273          26.337430          25.559602
# 4          20.467884          23.893858          29.156274          27.695178
#
#    SoilMoisture37_39  SoilMoisture38_40
# 0          28.678156          26.308484
# 1          29.079177          26.927224
# 2          19.564788          16.681692
# 3          27.611729          25.575794
# 4          29.255386          27.199097
#
# [5 rows x 166 columns]

# %%
# Labels are the values we want to predict
labels = np.array(aafc_data['YieldKgAcre'])
# Remove the labels from the features
# axis 1 refers to the columns
features= aafc_data.drop(['YieldKgAcre','YEAR','TWP_ID','Unnamed: 0','ECODISTRICT_ID'], axis = 1)
# Saving feature names for later use
feature_list = list(features.columns)
# Convert to numpy array
features = np.array(features)

# %%
pd.set_option('display.max_rows', None)
aafc_data.isnull().sum()
# Out:
# Unnamed: 0           0
# TWP_ID               0
# ECODISTRICT_ID       0
# YEAR                 0
# YieldKgAcre          0
# SumPcpn18_20         0
# SumPcpn19_21         0
# SumPcpn20_22         0
# SumPcpn21_23         0
# SumPcpn22_24         0
# SumPcpn23_25         0
# SumPcpn24_26         0
# SumPcpn25_27         0
# SumPcpn26_28         0
# SumPcpn27_29         0
# SumPcpn28_30         0
# SumPcpn29_31         0
# SumPcpn30_32         0
# SumPcpn31_33         0
# SumPcpn32_34         0
# SumPcpn33_35         0
# SumPcpn34_36         0
# SumPcpn35_37         0
# SumPcpn36_38         0
# SumPcpn37_39         0
# SumPcpn38_40         0
# SumEGDD_C18_20       0
# SumEGDD_C19_21       0
# SumEGDD_C20_22       0
# SumEGDD_C21_23       0
# SumEGDD_C22_24       0
# SumEGDD_C23_25       0
# SumEGDD_C24_26       0
# SumEGDD_C25_27       0
# SumEGDD_C26_28       0
# SumEGDD_C27_29       0
# SoilMoisture25_27    0
# SoilMoisture26_28    0
# SoilMoisture27_29    0
# SoilMoisture28_30    0
# SoilMoisture29_31    0
# SoilMoisture30_32    0
# SoilMoisture31_33    0
# SoilMoisture32_34    0
# SoilMoisture33_35    0
# SoilMoisture34_36    0
# SoilMoisture35_37    0
# SoilMoisture36_38    0
# SoilMoisture37_39    0
# SoilMoisture38_40    0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split
# Split the data into training and testing sets
train_features, test_features, train_labels, test_labels = train_test_split(features, labels, test_size = 0.25, random_state = 42)

# %%
print('Training Features Shape:', train_features.shape)
print('Training Labels Shape:', train_labels.shape)
print('Testing Features Shape:', test_features.shape)
print('Testing Labels Shape:', test_labels.shape)
# Out:
# Training Features Shape: (31505, 161)
# Training Labels Shape: (31505,)
# Testing Features Shape: (10502, 161)
# Testing Labels Shape: (10502,)

# %%
# Import the model we are using
from sklearn.ensemble import RandomForestRegressor
# Instantiate model with 1000 decision trees
rf = RandomForestRegressor(n_estimators = 1000, random_state = 42)
# Train the model on training data
rf.fit(train_features, train_labels);

# %%
# Get numerical feature importances
importances = list(rf.feature_importances_)
# List of tuples with variable and importance
feature_importances = [(feature, round(importance, 2)) for feature, importance in zip(feature_list, importances)]
# Sort the feature importances by most important first
feature_importances = sorted(feature_importances, key = lambda x: x[1], reverse = True)
# Print out the feature and importances 
[print('Variable: {:20} Importance: {}'.format(*pair)) for pair in feature_importances];
# Out:
# Variable: NDVI28_30            Importance: 0.22
# Variable: SumEGDD_C21_23       Importance: 0.07
# Variable: SumEGDD_C28_30       Importance: 0.07
# Variable: SumFrostD18_20       Importance: 0.03
# Variable: NDVI29_31            Importance: 0.03
# Variable: SoilMoisture23_25    Importance: 0.03
# Variable: SoilMoisture24_26    Importance: 0.03
# Variable: SumEGDD_C34_36       Importance: 0.02
# Variable: SumEGDD_C38_40       Importance: 0.02
# Variable: NDVI30_32            Importance: 0.02
# Variable: NDVI36_38            Importance: 0.02
# Variable: SoilMoisture30_32    Importance: 0.02
# Variable: SumPcpn36_38         Importance: 0.01
# Variable: SumPcpn38_40         Importance: 0.01
# Variable: SumEGDD_C30_32       Importance: 0.01
# Variable: SumEGDD_C32_34       Importance: 0.01
# Variable: AvgSI21_23           Importance: 0.01
# Variable: AvgSI27_29           Importance: 0.01
# Variable: AvgPrcnAWHC24_26     Importance: 0.01
# Variable: AvgPrcnAWHC26_28     Importance: 0.01
# Variable: NDVI18_20            Importance: 0.01
# Variable: NDVI19_21            Importance: 0.01
# Variable: NDVI20_22            Importance: 0.01
# Variable: NDVI21_23            Importance: 0.01
# Variable: NDVI24_26            Importance: 0.01
# Variable: NDVI25_27            Importance: 0.01
# Variable: NDVI26_28            Importance: 0.01
# Variable: NDVI27_29            Importance: 0.01
# Variable: NDVI31_33            Importance: 0.01
# Variable: NDVI32_34            Importance: 0.01
# Variable: NDVI33_35            Importance: 0.01
# Variable: NDVI34_36            Importance: 0.01
# Variable: NDVI35_37            Importance: 0.01
# Variable: SoilMoisture25_27    Importance: 0.01
# Variable: SoilMoisture26_28    Importance: 0.01
# Variable: SoilMoisture27_29    Importance: 0.01
# Variable: SoilMoisture28_30    Importance: 0.01
# Variable: SoilMoisture29_31    Importance: 0.01
# Variable: SoilMoisture31_33    Importance: 0.01
# Variable: SoilMoisture32_34    Importance: 0.01
# Variable: SoilMoisture33_35    Importance: 0.01
# Variable: SoilMoisture34_36    Importance: 0.01
# Variable: SoilMoisture35_37    Importance: 0.01
# Variable: SoilMoisture36_38    Importance: 0.01
# Variable: SoilMoisture37_39    Importance: 0.01
# Variable: SoilMoisture38_40    Importance: 0.01
# Variable: SumPcpn18_20         Importance: 0.0
# Variable: SumPcpn19_21         Importance: 0.0
# Variable: SumPcpn20_22         Importance: 0.0
# Variable: SumPcpn21_23         Importance: 0.0
# Variable: SumPcpn22_24         Importance: 0.0
# Variable: SumPcpn23_25         Importance: 0.0
# Variable: SumPcpn24_26         Importance: 0.0
# Variable: SumPcpn25_27         Importance: 0.0
# Variable: SumPcpn26_28         Importance: 0.0
# Variable: SumPcpn27_29         Importance: 0.0
# Variable: SumPcpn28_30         Importance: 0.0
# Variable: SumPcpn29_31         Importance: 0.0
# Variable: SumPcpn30_32         Importance: 0.0
# Variable: SumPcpn31_33         Importance: 0.0
# Variable: SumPcpn32_34         Importance: 0.0
# Variable: SumPcpn33_35         Importance: 0.0
# Variable: SumPcpn34_36         Importance: 0.0
# Variable: SumPcpn35_37         Importance: 0.0
# Variable: SumPcpn37_39         Importance: 0.0
# Variable: SumEGDD_C18_20       Importance: 0.0
# Variable: SumEGDD_C19_21       Importance: 0.0
# Variable: SumEGDD_C20_22       Importance: 0.0
# Variable: SumEGDD_C22_24       Importance: 0.0
# Variable: SumEGDD_C23_25       Importance: 0.0
# Variable: SumEGDD_C24_26       Importance: 0.0
# Variable: SumEGDD_C25_27       Importance: 0.0
# Variable: SumEGDD_C26_28       Importance: 0.0
# Variable: SumEGDD_C27_29       Importance: 0.0
# Variable: SumEGDD_C29_31       Importance: 0.0
# Variable: SumEGDD_C31_33       Importance: 0.0
# Variable: SumEGDD_C33_35       Importance: 0.0
# Variable: SumEGDD_C35_37       Importance: 0.0
# Variable: SumEGDD_C36_38       Importance: 0.0
# Variable: SumEGDD_C37_39       Importance: 0.0
# Variable: SumHeatD18_20        Importance: 0.0
# Variable: SumHeatD19_21        Importance: 0.0
# Variable: SumHeatD20_22        Importance: 0.0
# Variable: SumHeatD21_23        Importance: 0.0
# Variable: SumHeatD22_24        Importance: 0.0
# Variable: SumHeatD23_25        Importance: 0.0
# Variable: SumHeatD24_26        Importance: 0.0
# Variable: SumHeatD25_27        Importance: 0.0
# Variable: SumHeatD26_28        Importance: 0.0
# Variable: SumHeatD27_29        Importance: 0.0
# Variable: SumHeatD28_30        Importance: 0.0
# Variable: SumHeatD29_31        Importance: 0.0
# Variable: SumHeatD30_32        Importance: 0.0
# Variable: SumHeatD31_33        Importance: 0.0
# Variable: SumHeatD32_34        Importance: 0.0
# Variable: SumHeatD33_35        Importance: 0.0
# Variable: SumHeatD34_36        Importance: 0.0
# Variable: SumHeatD35_37        Importance: 0.0
# Variable: SumHeatD36_38        Importance: 0.0
# Variable: SumHeatD37_39        Importance: 0.0
# Variable: SumHeatD38_40        Importance: 0.0
# Variable: SumFrostD19_21       Importance: 0.0
# Variable: SumFrostD20_22       Importance: 0.0
# Variable: SumFrostD21_23       Importance: 0.0
# Variable: SumFrostD22_24       Importance: 0.0
# Variable: SumFrostD23_25       Importance: 0.0
# Variable: SumFrostD24_26       Importance: 0.0
# Variable: SumFrostD25_27       Importance: 0.0
# Variable: SumFrostD26_28       Importance: 0.0
# Variable: SumFrostD27_29       Importance: 0.0
# Variable: SumFrostD28_30       Importance: 0.0
# Variable: SumFrostD29_31       Importance: 0.0
# Variable: SumFrostD30_32       Importance: 0.0
# Variable: SumFrostD31_33       Importance: 0.0
# Variable: SumFrostD32_34       Importance: 0.0
# Variable: SumFrostD33_35       Importance: 0.0
# Variable: SumFrostD34_36       Importance: 0.0
# Variable: SumFrostD35_37       Importance: 0.0
# Variable: SumFrostD36_38       Importance: 0.0
# Variable: SumFrostD37_39       Importance: 0.0
# Variable: SumFrostD38_40       Importance: 0.0
# Variable: AvgSI18_20           Importance: 0.0
# Variable: AvgSI19_21           Importance: 0.0
# Variable: AvgSI20_22           Importance: 0.0
# Variable: AvgSI22_24           Importance: 0.0
# Variable: AvgSI23_25           Importance: 0.0
# Variable: AvgSI24_26           Importance: 0.0
# Variable: AvgSI25_27           Importance: 0.0
# Variable: AvgSI26_28           Importance: 0.0
# Variable: AvgSI28_30           Importance: 0.0
# Variable: AvgSI29_31           Importance: 0.0
# Variable: AvgSI30_32           Importance: 0.0
# Variable: AvgSI31_33           Importance: 0.0
# Variable: AvgSI32_34           Importance: 0.0
# Variable: AvgSI33_35           Importance: 0.0
# Variable: AvgSI34_36           Importance: 0.0
# Variable: AvgSI35_37           Importance: 0.0
# Variable: AvgSI36_38           Importance: 0.0
# Variable: AvgSI37_39           Importance: 0.0
# Variable: AvgSI38_40           Importance: 0.0
# Variable: AvgPrcnAWHC18_20     Importance: 0.0
# Variable: AvgPrcnAWHC19_21     Importance: 0.0
# Variable: AvgPrcnAWHC20_22     Importance: 0.0
# Variable: AvgPrcnAWHC21_23     Importance: 0.0
# Variable: AvgPrcnAWHC22_24     Importance: 0.0
# Variable: AvgPrcnAWHC23_25     Importance: 0.0
# Variable: AvgPrcnAWHC25_27     Importance: 0.0
# Variable: AvgPrcnAWHC27_29     Importance: 0.0
# Variable: AvgPrcnAWHC28_30     Importance: 0.0
# Variable: AvgPrcnAWHC29_31     Importance: 0.0
# Variable: AvgPrcnAWHC30_32     Importance: 0.0
# Variable: AvgPrcnAWHC31_33     Importance: 0.0
# Variable: AvgPrcnAWHC32_34     Importance: 0.0
# Variable: AvgPrcnAWHC33_35     Importance: 0.0
# Variable: AvgPrcnAWHC34_36     Importance: 0.0
# Variable: AvgPrcnAWHC35_37     Importance: 0.0
# Variable: AvgPrcnAWHC36_38     Importance: 0.0
# Variable: AvgPrcnAWHC37_39     Importance: 0.0
# Variable: AvgPrcnAWHC38_40     Importance: 0.0
# Variable: NDVI22_24            Importance: 0.0
# Variable: NDVI23_25            Importance: 0.0

# %%
predictions = rf.predict(test_features)
# Calculate the absolute errors
errors = abs(predictions - test_labels)
# Print out the mean absolute error (mae)
print('Mean Absolute Error:', round(np.mean(errors), 2), 'degrees.')
# Out:
# Mean Absolute Error: 74.68 degrees.

# %%
# Calculate mean absolute percentage error (MAPE)
mape = 100 * (errors / test_labels)
# Calculate and display accuracy
accuracy = 100 - np.mean(mape)
print('Accuracy:', round(accuracy, 2), '%.')
# Out:
# Accuracy: 89.42 %.
