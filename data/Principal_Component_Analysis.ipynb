# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import pandas as pd

# %%
df = pd.read_csv('final_data.csv')

# %%
df.head(10)
# Out:
#      TWP_ID  ECODISTRICT_ID  YEAR  YieldKgAcre  SumPcpn18_20  SumPcpn19_21  \
# 0  1.01E+03             852  2010   867.766846          53.6         111.1
# 1   00101W1             852  2010   673.685028          57.2         114.7
# 2   00101W2             796  2010   824.303864          39.0          96.4
# 3  1.02E+03             853  2010  1006.708496          37.5         158.2
# 4   00102W1             852  2010   869.040283          57.2         114.7
# 5   00102W2             796  2010   823.876709          29.8          59.0
# 6  1.03E+03             853  2010   820.111633          37.5         158.2
# 7   00103W1             852  2010  1161.746033          86.9         116.2
# 8   00103W2             796  2010   742.240295          29.8          59.0
# 9  1.04E+03             726  2010   726.107849          37.5         158.2
#
#    SumPcpn20_22  SumPcpn21_23  SumPcpn22_24  SumPcpn23_25  ...  \
# 0         109.7         117.9          46.4          69.3  ...
# ...

# %%
df.drop(['TWP_ID','ECODISTRICT_ID','YEAR'], axis=1, inplace= True)

# %%
df.head()
# Out:
#    YieldKgAcre  SumPcpn18_20  SumPcpn19_21  SumPcpn20_22  SumPcpn21_23  \
# 0   867.766846          53.6         111.1         109.7         117.9
# 1   673.685028          57.2         114.7         110.5         114.0
# 2   824.303864          39.0          96.4         109.8         101.2
# 3  1006.708496          37.5         158.2         157.8         161.4
# 4   869.040283          57.2         114.7         110.5         114.0
#
#    SumPcpn22_24  SumPcpn23_25  SumPcpn24_26  SumPcpn25_27  SumPcpn26_28  ...  \
# 0          46.4          69.3          60.0          44.6          29.9  ...
# 1          46.2          68.1          55.9          34.9          29.6  ...
# 2         111.4         153.0         163.6          98.8          42.4  ...
# 3          46.9          79.5          67.5          40.4           6.6  ...
# 4          46.2          68.1          55.9          34.9          29.6  ...
#
# ...

# %%
Y = df['YieldKgAcre']

# %%
df.drop('YieldKgAcre', axis=1, inplace= True)

# %%
df.head()
# Out:
#    SumPcpn18_20  SumPcpn19_21  SumPcpn20_22  SumPcpn21_23  SumPcpn22_24  \
# 0          53.6         111.1         109.7         117.9          46.4
# 1          57.2         114.7         110.5         114.0          46.2
# 2          39.0          96.4         109.8         101.2         111.4
# 3          37.5         158.2         157.8         161.4          46.9
# 4          57.2         114.7         110.5         114.0          46.2
#
#    SumPcpn23_25  SumPcpn24_26  SumPcpn25_27  SumPcpn26_28  SumPcpn27_29  ...  \
# 0          69.3          60.0          44.6          29.9          52.4  ...
# 1          68.1          55.9          34.9          29.6          59.5  ...
# 2         153.0         163.6          98.8          42.4          24.4  ...
# 3          79.5          67.5          40.4           6.6          49.6  ...
# 4          68.1          55.9          34.9          29.6          59.5  ...
#
# ...

# %%
X = df

# %%
# test_size: what proportion of original data is used for test set
train_img, test_img, train_lbl, test_lbl = train_test_split(X, Y, test_size=0.2, random_state=1)

# %%
scaler = StandardScaler()
# Fit on training set only.
scaler.fit(train_img)
# Apply transform to both the training set and the test set.
train_img = scaler.transform(train_img)
test_img = scaler.transform(test_img)

# %%
# Make an instance of the Model
pca = PCA(.95)

# %%
train_image = pca.fit_transform(train_img)

# %%
pca.n_components_
# Out:
# 40

# %%
test_img = pca.transform(test_img)

# %%
train_image.shape
# Out:
# (33605, 40)

# %%
principalDf = pd.DataFrame(
train_image, 
    columns = [
    'pc 1', 
    'pc 2',
    'pc 3', 
    'pc 4',
    'pc 5', 
    'pc 6',
    'pc 7', 
    'pc 8',
    'pc 9', 
    'pc 10',
    'pc 11', 
    'pc 12',
    'pc 13', 
    'pc 14',
    'pc 15', 
    'pc 16',
    'pc 17', 
    'pc 18',
    'pc 19', 
    'pc 20',
    'pc 21', 
    'pc 22',
    'pc 23', 
    'pc 24',
    'pc 25', 
    'pc 26',
    'pc 27', 
    'pc 28',
    'pc 29', 
    'pc 30',
    'pc 31', 
    'pc 32',
    'pc 33', 
    'pc 34',
    'pc 35', 
    'pc 36',
    'pc 37', 
    'pc 38',
    'pc 39',
    'pc 40'
    ]
)

# %%
principalDf.head()
# Out:
#        pc 1      pc 2      pc 3      pc 4      pc 5      pc 6      pc 7  \
# 0  0.981490 -4.104351 -3.075636  1.672974  2.288725 -4.588676 -0.909914
# 1 -7.791216  2.613004  0.830375 -1.025651  3.416493  3.389481  1.251507
# 2 -0.376696  7.322101 -1.072659 -2.608636 -0.538741 -1.348603 -0.192584
# 3  5.457436 -5.720625  5.474761  5.098252 -0.736394 -1.571867 -2.363899
# 4  2.259284 -2.850893  5.778290 -4.968689 -6.442701 -0.346797  0.748776
#
#        pc 8      pc 9     pc 10  ...     pc 31     pc 32     pc 33     pc 34  \
# 0  3.306961  3.627524 -1.279427  ... -1.218258 -0.286630  0.599988 -1.454460
# 1 -0.126173 -2.352365  2.371180  ... -0.860122 -1.037386  1.067690  0.980582
# 2 -0.643278 -1.783858 -1.137858  ... -0.318585  0.613806 -0.606472 -0.153541
# 3 -0.656865 -2.260579 -3.702239  ...  1.410063  0.126420 -0.655503 -0.622267
# 4  0.143758  3.315815  0.834805  ... -0.345381 -1.003507  1.752235  0.880358
#
#       pc 35     pc 36     pc 37     pc 38     pc 39     pc 40
# ...

# %%
finalDf = pd.concat([principalDf, Y], axis = 1)

# %%
finalDf.head()
# Out:
#        pc 1      pc 2      pc 3      pc 4      pc 5      pc 6      pc 7  \
# 0  0.981490 -4.104351 -3.075636  1.672974  2.288725 -4.588676 -0.909914
# 1 -7.791216  2.613004  0.830375 -1.025651  3.416493  3.389481  1.251507
# 2 -0.376696  7.322101 -1.072659 -2.608636 -0.538741 -1.348603 -0.192584
# 3  5.457436 -5.720625  5.474761  5.098252 -0.736394 -1.571867 -2.363899
# 4  2.259284 -2.850893  5.778290 -4.968689 -6.442701 -0.346797  0.748776
#
#        pc 8      pc 9     pc 10  ...     pc 32     pc 33     pc 34     pc 35  \
# 0  3.306961  3.627524 -1.279427  ... -0.286630  0.599988 -1.454460  2.156702
# 1 -0.126173 -2.352365  2.371180  ... -1.037386  1.067690  0.980582 -0.460453
# 2 -0.643278 -1.783858 -1.137858  ...  0.613806 -0.606472 -0.153541  0.899754
# 3 -0.656865 -2.260579 -3.702239  ...  0.126420 -0.655503 -0.622267  0.510734
# 4  0.143758  3.315815  0.834805  ... -1.003507  1.752235  0.880358  0.088558
#
#       pc 36     pc 37     pc 38     pc 39     pc 40  YieldKgAcre
# ...
