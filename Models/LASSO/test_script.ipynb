# %% [markdown]
# ## Importing Packages and Modules and necessary Libraries

# %%
from lasso_aafc.LASSO import lasso_ecodistrict_model_validation_scoring
from lasso_aafc.LASSO import lasso_ecodistrict_model_fit

# %% [markdown]
# ## Importing Wrangled and Clean Dataset

# %%
import pandas as pd
data=pd.read_csv("aafc_data.csv",index_col='Unnamed: 0')

# %% [markdown]
# ## Instantiating the object of the Class by passing data and Ecodistrict ID

# %%
test=lasso_ecodistrict_model_validation_scoring(data,748)

# %% [markdown]
# ## Show LASSO Model Performance Metrics

# %%
test.validation_metrics()
# Out:
# Mean Squared Error Train:  78.23
# Mean Squared Error Test:  82.73
# Mean Absolute Error:  63.72
# Accuracy:  90.73

# %% [markdown]
# ## Show Predicted Crop Yield on Training Dataset

# %%
test.predicted_train_dataset()
# Out:
#         TWP_ID  ECODISTRICT_ID  YEAR  SumPcpn18_20  SumPcpn19_21  \
# 13295  02213W2           748.0  2013           6.1           2.3
# 13831  02914W2           748.0  2013          15.1          16.2
# 2361   02908W2           748.0  2010          31.0          53.0
# 29253  03118W2           748.0  2017           7.9          17.6
# 5880   02511W2           748.0  2011          31.4          53.0
# ...        ...             ...   ...           ...           ...
# 36658  02807W2           748.0  2019          10.1           6.0
# 40089  02308W2           748.0  2020          16.8           9.1
# 40331  02610W2           748.0  2020          16.8           9.1
# 29236  03110W2           748.0  2017           7.9          17.6
# 40267  02518W2           748.0  2020           7.7          11.7
#
#        SumPcpn20_22  SumPcpn21_23  SumPcpn22_24  SumPcpn23_25  SumPcpn24_26  \
# 13295          20.2          36.9          59.2          71.8          85.9
# ...

# %% [markdown]
# ## Show Predicted Crop Yield on Testing Dataset

# %%
test.predicted_test_dataset()
# Out:
#         TWP_ID  ECODISTRICT_ID  YEAR  SumPcpn18_20  SumPcpn19_21  \
# 40624  03009W2           748.0  2020          16.8           9.1
# 29246  03115W2           748.0  2017           7.9          17.6
# 2513   03115W2           748.0  2010          52.0          65.0
# 17112  02212W2           748.0  2014          28.5          22.5
# 2232   02715W2           748.0  2010          52.0          65.0
# ...        ...             ...   ...           ...           ...
# 13682  02712W2           748.0  2013          15.1          16.2
# 29250  03117W2           748.0  2017           7.9          17.6
# 17853  03215W2           748.0  2014          17.9          12.4
# 40705  03116W2           748.0  2020          18.4          16.7
# 32384  02210W2           748.0  2018          13.1          26.6
#
#        SumPcpn20_22  SumPcpn21_23  SumPcpn22_24  SumPcpn23_25  SumPcpn24_26  \
# 40624           6.5          17.0          22.3          22.1          21.1
# ...

# %% [markdown]
# ## Show the feature importance

# %%
test.feature_importance()
# Out:
#              features  importance
# 12     SumEGDD_C18_20   76.757079
# 49          NDVI31_33   71.043833
# 60  SoilMoisture38_40   61.515620
# 56  SoilMoisture28_30   59.865573
# 13     SumEGDD_C23_25   58.493469
# ..                ...         ...
# 24      SumHeatD30_32    1.460051
# 53  SoilMoisture23_25    0.731185
# 20      SumHeatD22_24    0.433603
# 6        SumPcpn29_31    0.181166
# 35     SumFrostD36_38    0.057411
#
# [61 rows x 2 columns]

# %% [markdown]
# ## Importing New Test Set

# %%
data_to_score=pd.read_csv("scoring_test_df.csv",index_col='Unnamed: 0')

# %% [markdown]
# ## Show Predicted Crop Yield on New Test Set

# %%
test.score(data_to_score)
# Out:
#         TWP_ID  ECODISTRICT_ID  YEAR  SumPcpn18_20  SumPcpn19_21  \
# 2996   03910W3           735.0  2010          69.3         110.9
# 3049   04011W3           735.0  2010          63.7         105.5
# 3098   04111W3           735.0  2010          63.7         105.5
# 3100   04112W3           735.0  2010          63.7         105.5
# 3102   04113W3           735.0  2010          63.7         105.5
# ...        ...             ...   ...           ...           ...
# 41563  04619W3           735.0  2020          12.8          58.4
# 41565  04620W3           735.0  2020          12.8          58.4
# 41567  04621W3           735.0  2020          12.8          58.4
# 41604  04718W3           735.0  2020          12.8          58.4
# 41610  04721W3           735.0  2020          12.8          58.4
#
#        SumPcpn20_22  SumPcpn21_23  SumPcpn22_24  SumPcpn23_25  SumPcpn24_26  \
# 2996          125.7          96.5          69.4          65.5         144.2
# ...

# %% [markdown]
# ## Display Info of Packages/Modules and Functions Used

# %%
print(lasso_ecodistrict_model_fit.__doc__)
# Out:
#     A class representing LASSO model having certain attributes and the methods
#     ...
#     Attributes
#     ----------
#     aafc_data : dataframe
#         Clean and Wrangled Crop Yield Dataset
#     ecodistrict : str
#         specific Ecodistrict region ID
#
#     Methods
#     -------
#     model_train_test(additional=""):
#         Fits the model after train test split

# %%
print(lasso_ecodistrict_model_fit.model_train_test.__doc__)
# Out:
#         Returns key datasets required for performing model evaluation metrics and predictions.
#         Parameters:
#                 self: Class Object
#         Returns:
#                 returns scaler,lin_reg_pc,train_features,test_features,train_labels,test_labels,train_index,test_index,pred_train,pred,best_pc_num,variance

# %%
print(lasso_ecodistrict_model_validation_scoring.__doc__)
# Out:
#     A child class used to evaluate LASSO Model and make predictions having its own attributes and the methods, as well as attributes and methods of its parent class
#     ...
#     Attributes
#     ----------
#     aafc_data : dataframe
#         Clean and Wrangled Crop Yield Dataset
#     ecodistrict : str
#         specific Ecodistrict region ID
#
#     Methods
#     -------
#     validation_metrics(additional=""):
#         Evaluates LASSO in terms of MSE Train, Test, Mean Absolute Error and Accuracy
#
#     predicted_train_dataset(additional=""):
#         Predicts the Crop Yield Prediction Based on Training Predictors
#     predicted_test_dataset(additional=""):
#         Predicts the Crop Yield Prediction Based on Testing Predictors
#     feature_importance(additional=""):
#         Return the exact variance explained by the principal components selected
#     score(additional=""):
#         Predicts the Crop Yield  based on new predictor data

# %%
print(lasso_ecodistrict_model_validation_scoring.validation_metrics.__doc__)
# Out:
#         Evaluates Model Performance and prints MSE Train,Test,Mean Absolute Error and Accuracy
#         Parameters:
#                 self: Class Object
#         Returns:
#                 None

# %%
print(lasso_ecodistrict_model_validation_scoring.predicted_train_dataset.__doc__)
# Out:
#         Returns the Predicted Crop Yield in the Training Set
#         Parameters:
#                 self: Class Object
#         Returns:
#                 returns train_index i.e., dataset with predicted values of crop yield based on training set predictors

# %%
print(lasso_ecodistrict_model_validation_scoring.predicted_test_dataset.__doc__)
# Out:
#         Returns the Predicted Crop Yield in the Testing Set
#         Parameters:
#                 self: Class Object
#         Returns:
#                 returns test_index i.e., dataset with predicted values of crop yield based on Testing set predictors

# %%
print(lasso_ecodistrict_model_validation_scoring.score.__doc__)
# Out:
#         Returns the Predicted Crop Yield in the new Data Set
#         Parameters:
#                 self: Class Object
#         Returns:
#                 returns data i.e., dataset with predicted values of crop yield based on New Dataset predictors
