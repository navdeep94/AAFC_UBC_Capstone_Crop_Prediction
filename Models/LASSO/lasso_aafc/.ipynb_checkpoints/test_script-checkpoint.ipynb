# %%
from LASSO_py import lasso_ecodistrict_model_fit
from LASSO_py import lasso_ecodistrict_model_validation

# %%
import pandas as pd
data=pd.read_csv("aafc_data.csv",index_col='Unnamed: 0')
# Out:
#         TWP_ID  ECODISTRICT_ID  YEAR  YieldKgAcre  SumPcpn18_20  SumPcpn19_21  \
# 0      00101E1           852.0  2010   867.766846          53.6         111.1
# 1      00101W1           852.0  2010   673.685028          57.2         114.7
# 2      00101W2           796.0  2010   824.303864          39.0          96.4
# 3      00102E1           853.0  2010  1006.708496          37.5         158.2
# 4      00102W1           852.0  2010   869.040283          57.2         114.7
# ...        ...             ...   ...          ...           ...           ...
# 42002  06322W3           680.0  2020   775.426025          11.1          30.8
# 42003  06323W3           652.0  2020   817.348999          11.1          30.8
# 42004  06324W3           680.0  2020  1078.681458          12.0          20.2
# 42005  06325W3           652.0  2020  1006.945190          12.0          20.2
# 42006  06326W3           652.0  2020  1032.783081          12.0          20.2
#
# ...

# %%
test=lasso_ecodistrict_model_validation(data,735)
test.validation_metrics()
#test.predicted_train_dataset()
#test.predicted_test_dataset()
# Out:
# Mean Squared Error Train:  80.31
# Mean Squared Error Test:  85.24
# Mean Squared Error Test:  85.24
# Mean Absolute Error:  63.56
# Accuracy:  92.55
